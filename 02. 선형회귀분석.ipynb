# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
num_points = 1000
vectors_set = []

for i in xrange(num_points):
    x1 = np.random.normal(0.0, 0.55)
    y1 = x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
    vectors_set.append([x1, y1])
    
x_data = [v[0] for v in vectors_set]
y_data = [v[1] for v in vectors_set]

# %%
plt.plot(x_data, y_data, 'ro')

# %%
import tensorflow as tf

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

# %%
loss = tf.reduce_mean(tf.square(y - y_data))

# %%
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# %%
init = tf.initialize_all_variables()

sess = tf.Session()
sess.run(init)

# %%
for step in xrange(8):
    sess.run(train)
    
print sess.run(W), sess.run(b)
# Out:
# [ 0.13327396] [ 0.29919949]

# %%
plt.plot(x_data, y_data, 'ro')
plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
# Out:
# //anaconda/envs/tensorflow/lib/python2.7/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
for step in xrange(8):
    sess.run(train)
    print step, sess.run(W), sess.run(b), sess.run(loss)
# Out:
# 0 [ 0.12354867] [ 0.29926345] 0.00105906
# 1 [ 0.11666565] [ 0.29930872] 0.000978149
# 2 [ 0.11179421] [ 0.29934075] 0.000937621
# 3 [ 0.10834648] [ 0.29936343] 0.00091732
# 4 [ 0.10590635] [ 0.2993795] 0.000907151
# 5 [ 0.10417937] [ 0.29939085] 0.000902058
# 6 [ 0.1029571] [ 0.2993989] 0.000899506
# 7 [ 0.10209204] [ 0.29940459] 0.000898228
